# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
from src.data_loader import load_raw_data
import src.features

# %%
dir(src.features)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']
