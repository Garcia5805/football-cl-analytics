# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
from src.data_loader import load_raw_data
from src.features import get_score

# %%
games = load_raw_data("uefacompetitionresults.csv", sep=";")
games = get_score(games)
games[['gh', 'ga', 'Score']].head(10)
# Out:
#    gh  ga  Score
# 0   0   5  0 - 5
# 1   3   3  3 - 3
# 2   6   3  6 - 3
# 3   0   2  0 - 2
# 4   0   4  0 - 4
# 5   0   0  0 - 0
# 6   0   2  0 - 2
# 7   6   1  6 - 1
# 8   5   0  5 - 0
# 9   5   2  5 - 2
